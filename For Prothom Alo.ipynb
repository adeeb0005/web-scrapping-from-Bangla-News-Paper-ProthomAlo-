# %% [markdown]
# # For Prothom Alo

# %% [markdown]
# ## for পঠিত

# %%
from datetime import date
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

website = 'https://www.prothomalo.com'
driver.get(website)


time.sleep(2)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")

# %% [markdown]
# ### উপরে স্ক্রোল করে, পঠিত সেকশনে নিয়ে যাও

# %%
all_pothito = driver.find_elements(By.XPATH,'//div[@class="numbered-story-headline-wrapper"]/a')
#driver.quit()

# %%
hdline = []
nslnk = []
for pothito in all_pothito:
    #print(pothito.text, "\t", pothito.get_attribute("href"))
    st = str(pothito.text)
    hdline.append(st[2:])
    nslnk.append(pothito.get_attribute("href"))

headline = []
news_body = []
news_link = []
dates = []
excel_data_df = pd.read_excel('pothito.xlsx')
dates = list(pd.to_datetime(excel_data_df['date'].values))
headline = list(excel_data_df['headline'].values)
news_body = list(excel_data_df['news'].values)
news_link = list(excel_data_df['link'].values)

today = date.today()
driver.quit()
for hd in hdline:
    headline.append(hd)
for lk in nslnk:
    news_link.append(lk)

# %%
for link in nslnk:
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.chrome.service import Service as ChromeService
    from webdriver_manager.chrome import ChromeDriverManager

    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

    driver.get(link)
    newses = driver.find_elements(By.XPATH,'//div[@class="story-element story-element-text"]/div/p')
    st = ""
    for newss in newses:
        st += str(newss.text)
    news_body.append(st)
    dates.append(str(today))
    driver.quit()

# %%
df = pd.DataFrame()
df['date']  = dates
df['headline'] = headline
df['news'] = news_body
df['link'] = news_link
df.to_excel('pothito.xlsx', index=False)
# Out:
# C:\Users\adeeb\AppData\Local\Temp\ipykernel_15156\141600576.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df['date']  = dates
# C:\Users\adeeb\AppData\Local\Temp\ipykernel_15156\141600576.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df['date']  = dates

# %% [markdown]
# ### for আলোচিত

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

website = 'https://www.prothomalo.com'
driver.get(website)


time.sleep(2)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")

# %%
all_alochito_button = driver.find_element(By.XPATH,'//h2[@class=" tab-headline"][1]')
all_alochito_button.click()

# %%
all_alochito = driver.find_elements(By.XPATH,'//div[@class="numbered-story-headline-wrapper"]/a')

# %%
hdline = []
nslnk = []
for alochito in all_alochito:
    #print(pothito.text, "\t", pothito.get_attribute("href"))
    st = str(alochito.text)
    hdline.append(st[2:])
    nslnk.append(alochito.get_attribute("href"))

headline = []
news_body = []
news_link = []
dates = []
excel_data_df = pd.read_excel('alochito.xlsx')
dates = list(pd.to_datetime(excel_data_df['date'].values))
headline = list(excel_data_df['headline'].values)
news_body = list(excel_data_df['news'].values)
news_link = list(excel_data_df['link'].values)

today = date.today()
driver.quit()
for hd in hdline:
    headline.append(hd)
for lk in nslnk:
    news_link.append(lk)

# %%
for link in nslnk:
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.chrome.service import Service as ChromeService
    from webdriver_manager.chrome import ChromeDriverManager

    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

    driver.get(link)
    newses = driver.find_elements(By.XPATH,'//div[@class="story-element story-element-text"]/div/p')
    st = ""
    for newss in newses:
        st += str(newss.text)
    news_body.append(st)
    dates.append(str(today))
    driver.quit()

# %%
df = pd.DataFrame()
df['date']  = dates
df['headline'] = headline
df['news'] = news_body
df['link'] = news_link
df.to_excel('alochito.xlsx', index=False)
# Out:
# C:\Users\adeeb\AppData\Local\Temp\ipykernel_15156\1855612104.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df['date']  = dates
# C:\Users\adeeb\AppData\Local\Temp\ipykernel_15156\1855612104.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df['date']  = dates

# %% [markdown]
# ### for all news

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

website = 'https://www.prothomalo.com'
driver.get(website)


time.sleep(2)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")

# %%
html = driver.find_elements(By.XPATH, '//a[@target ="_self"]')

# %%
banner = []
links = []

# %%
for ht in html:
    try:
        banner.append(ht.get_attribute("aria-label"))
        links.append(ht.get_attribute("href"))
    except:
        print("problems")

# %%
links
# Out:
# ['https://www.prothomalo.com/photo/bangladesh/kru0llt9i9',
#  'https://www.prothomalo.com/video/bangladesh/4usa54reqc',
#  'https://www.prothomalo.com/video/bangladesh/mtzvuj7yj3',
#  'https://www.prothomalo.com/search',
#  'https://www.prothomalo.com/collection/latest',
#  'https://www.prothomalo.com/politics',
#  'https://www.prothomalo.com/bangladesh',
#  'https://www.prothomalo.com/bangladesh/crime',
#  'https://www.prothomalo.com/world',
#  'https://www.prothomalo.com/business',
#  'https://www.prothomalo.com/opinion',
#  'https://www.prothomalo.com/sports',
#  'https://www.prothomalo.com/entertainment',
#  'https://www.prothomalo.com/chakri',
#  'https://www.prothomalo.com/lifestyle',
#  'https://www.prothomalo.com/search',
#  'https://www.prothomalo.com/photo/bangladesh/kru0llt9i9',
#  'https://www.prothomalo.com/video/bangladesh/4usa54reqc',
#  'https://www.prothomalo.com/video/bangladesh/mtzvuj7yj3',
#  'https://www.prothomalo.com/bangladesh/crime/5gfb3jpeip',
#  'https://www.prothomalo.com/bangladesh/tuaps85zal',
#  'https://www.prothomalo.com/politics/0oz53w42jt',
#  'https://www.prothomalo.com/bangladesh/district/6o3j4a1oux',
#  'https://www.prothomalo.com/business/jw39g2potp',
#  'https://www.prothomalo.com/bangladesh/district/04in3cd75c',
#  'https://www.prothomalo.com/opinion/column/uajtkyzgk8',
#  'https://www.prothomalo.com/opinion/column/8beohhxqdw',
#  'https://www.prothomalo.com/politics/tlfedfwa0i',
#  'https://www.prothomalo.com/bangladesh/8q0uktz65r',
#  'https://www.prothomalo.com/politics/xojbyaqui9',
#  'https://www.prothomalo.com/sports/football/dc8k8zg9bf',
#  'https://www.prothomalo.com/sports/football/0tqdyub2cz',
#  'https://www.prothomalo.com/politics/p0o0b1plml',
#  'https://www.prothomalo.com/bangladesh/6vq20727lk',
#  'https://www.prothomalo.com/bangladesh/environment/ixskhbm6kk',
#  'https://www.prothomalo.com/bangladesh/8c4u2ejz6u',
#  'https://www.prothomalo.com/bangladesh/uqnpsz4bvs',
#  'https://www.prothomalo.com/politics/rzln7b56hv',
#  'https://www.prothomalo.com/bangladesh/crime/5gfb3jpeip',
#  'https://www.prothomalo.com/bangladesh/tuaps85zal',
#  'https://www.prothomalo.com/politics/0oz53w42jt',
#  'https://www.prothomalo.com/bangladesh/district/6o3j4a1oux',
#  'https://www.prothomalo.com/business/jw39g2potp',
#  'https://www.prothomalo.com/bangladesh/district/04in3cd75c',
#  'https://www.prothomalo.com/opinion/column/uajtkyzgk8',
#  'https://www.prothomalo.com/opinion/column/8beohhxqdw',

#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/glimpse/zbo2jdtyz4',
#  'https://www.prothomalo.com/photo/bangladesh/kru0llt9i9',
#  'https://www.prothomalo.com/photo/glimpse/d65xq84fp1',
#  'https://www.prothomalo.com/photo/bangladesh/gq9xfo7meu',
#  'https://www.prothomalo.com/photo/bangladesh/khjk0f2chs',
#  'https://www.prothomalo.com/video',
#  'https://www.prothomalo.com/video/sports/vtv7b4e7x4',
#  'https://www.prothomalo.com/video/bangladesh/4u8n0ikp4j',
#  'https://www.prothomalo.com/video/bangladesh/m3dslelyrl',
#  'https://www.prothomalo.com/video/bangladesh/4usa54reqc',
#  'https://www.prothomalo.com/video/bangladesh/mtzvuj7yj3',
#  'https://www.prothomalo.com/education',
#  'https://www.prothomalo.com/education/examination/plqloh4utx',
#  'https://www.prothomalo.com/education/examination/r5ir4e9t40',
#  'https://www.prothomalo.com/education/scholarship/rqzzvvydbo',
#  'https://www.prothomalo.com/chakri',
#  'https://www.prothomalo.com/chakri/chakri-news/3j7u3tdh7b',
#  'https://www.prothomalo.com/chakri/chakri-news/y7gggd0v49',
#  'https://www.prothomalo.com/chakri/chakri-news/0wxwpbz9c5',
#  'https://www.prothomalo.com/technology',
#  'https://www.prothomalo.com/technology/xee6rk8lsp',
#  'https://www.prothomalo.com/technology/hursvjwps3',
#  'https://www.prothomalo.com/technology/science/ucq1fcijtu',
#  'https://www.prothomalo.com/technology/gadget',
#  'https://www.prothomalo.com/technology/gadget/cjwzndfmgz',
#  'https://www.prothomalo.com/technology/gadget/hla1dyuf94',
#  'https://www.prothomalo.com/technology/gadget/l5nbcxokzg',
#  'https://www.prothomalo.com/onnoalo',
#  'https://www.prothomalo.com/onnoalo/9nqdauy672',
#  'https://www.prothomalo.com/onnoalo/3jwccz4ru9',
#  'https://www.prothomalo.com/onnoalo/stories/lfzqnnfo44',
#  'https://www.prothomalo.com/religion',
#  'https://www.prothomalo.com/religion/islam/ncy8adlhst',
#  'https://www.prothomalo.com/religion/islam/4eyeu6rz6v',
#  'https://www.prothomalo.com/religion/islam/uaxjyaupsm',
#  'https://www.prothomalo.com/mobile-vas',
#  'https://www.prothomalo.com/circulation',
#  'https://www.prothomalo.com/privacy-policy']

# %%
tag_links = ['https://www.prothomalo.com/politics', 
'https://www.prothomalo.com/bangladesh', 
'https://www.prothomalo.com/bangladesh/crime', 
'https://www.prothomalo.com/world', 
'https://www.prothomalo.com/business', 
'https://www.prothomalo.com/opinion', 
'https://www.prothomalo.com/sports', 
'https://www.prothomalo.com/entertainment', 
'https://www.prothomalo.com/chakri', 
'https://www.prothomalo.com/lifestyle', 
'https://www.prothomalo.com/anniversary', 
'https://www.prothomalo.com/education', 
'https://www.prothomalo.com/chakri', 
'https://www.prothomalo.com/technology', 
'https://www.prothomalo.com/technology/gadget', 
'https://www.prothomalo.com/onnoalo', 
'https://www.prothomalo.com/religion']

# %%
news_links = []

# %%
for tglk in tag_links:
    x = [link for link in links if link.startswith(tglk) and len(link) > len(tglk)]
    news_links.extend(x)

# %%
news_links = list(set(news_links))

# %%
total_news_links = []

# %%
for nwlk in news_links:
#  'https://www.prothomalo.com/bangladesh/4l4cuvqu1j',
#  'https://www.prothomalo.com/lifestyle/fashion/26rfmwvbw7',
#  'https://www.prothomalo.com/business/world-business/21zhjzc3zj',
#  'https://www.prothomalo.com/entertainment/ott/i2dep7uoil',
#  'https://www.prothomalo.com/politics/tlfedfwa0i',
#  'https://www.prothomalo.com/bangladesh/q1z607ysav',
#  'https://www.prothomalo.com/sports/football/3qzkdnh18s',
#  'https://www.prothomalo.com/bangladesh/8c4u2ejz6u',
#  'https://www.prothomalo.com/technology/xee6rk8lsp',
#  'https://www.prothomalo.com/business/jw39g2potp',
#  'https://www.prothomalo.com/opinion/column/orz40lwt7d',
#  'https://www.prothomalo.com/entertainment/bollywood/bgcgbsjbo8',
#  'https://www.prothomalo.com/world/1af0qmv4zq',
#  'https://www.prothomalo.com/bangladesh/crime/5gfb3jpeip',
#  'https://www.prothomalo.com/bangladesh/district/04in3cd75c',
#  'https://www.prothomalo.com/religion/islam/4eyeu6rz6v',
#  'https://www.prothomalo.com/bangladesh/8q0uktz65r',
#  'https://www.prothomalo.com/bangladesh/district/t90h2k7enu',
#  'https://www.prothomalo.com/politics/0oz53w42jt',
#  'https://www.prothomalo.com/opinion/column/8beohhxqdw',
#  'https://www.prothomalo.com/lifestyle/yvrv6psqj9',
#  'https://www.prothomalo.com/religion/islam/ncy8adlhst',
#  'https://www.prothomalo.com/technology/gadget/hla1dyuf94',
#  'https://www.prothomalo.com/entertainment/tollywood/muckscv5v6',
#  'https://www.prothomalo.com/politics/rzln7b56hv',
#  'https://www.prothomalo.com/bangladesh/uqnpsz4bvs',
#  'https://www.prothomalo.com/entertainment/bollywood/ab5rwynbt5',
#  'https://www.prothomalo.com/lifestyle/travel/emqd8c21h9',
#  'https://www.prothomalo.com/world/pakistan/0mga60arlp',
#  'https://www.prothomalo.com/sports/football/0tqdyub2cz',
#  'https://www.prothomalo.com/technology/gadget/l5nbcxokzg',
#  'https://www.prothomalo.com/business/y9o82ii9i4',
#  'https://www.prothomalo.com/sports/football/t7301cqs47',
#  'https://www.prothomalo.com/entertainment/bollywood/719gjr6xws',
#  'https://www.prothomalo.com/lifestyle/%E0%A6%AD%E0%A7%82%E0%A6%AE%E0%A6%BF%E0%A6%95%E0%A6%AE%E0%A7%8D%E0%A6%AA']

# %%
len(total_news_links)
new_links = []
headline = []
news_body = []
dates = []

# %%
for link in total_news_links:
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.chrome.service import Service as ChromeService
    from webdriver_manager.chrome import ChromeDriverManager

    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

    driver.get(link)
    newses = driver.find_elements(By.XPATH,'//div[@class="story-element story-element-text"]/div/p')
    sa = ""
    try:
        heading = driver.find_element(By.XPATH, '//div/h1')
        sa = heading.text
    except:
        sa = ""
    st = ""
    for newss in newses:
        st += str(newss.text)
    news_body.append(st)
    dates.append(str(today))
    new_links.append(link)
    headline.append(sa)
    driver.quit()

# %%
df = pd.DataFrame()
df['date']  = dates
df['headline'] = headline
df['news'] = news_body
df['link'] = new_links
df.to_excel('all news.xlsx', index=False)
